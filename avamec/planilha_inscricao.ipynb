# %% [markdown]
# 1 - Importações

# %%
# Importar bibliotecas necessárias
import pandas as pd
import os
# !pip install -q pandas openpyxl

# %% [markdown]
# 2 - Definição de constantes

# %%
# Define file paths
turma_a_cursistas_file = '/home/emanoel/Downloads/avamec_inscricoes/Cursistas Turma A/Cursistas Turma_A.xlsx'
turma_b_cursistas_file = '/home/emanoel/Downloads/avamec_inscricoes/Cursistas Turma B/Cursistas Turma_B.xlsx'

# Define matching columns
matching_column_cursistas = '[0] login'
matching_column_ava = 'Login do Membro'
error_column_ava = 'Erro Apresentado?'
login_existente_column = 'Login existente'

# %%
def verificar_arquivos_existem(turma_a_cursistas_file, emails_file=None):
    """
    Verifica se os arquivos necessários existem.
    
    Args:
        cursistas_file (str): Caminho para o arquivo de cursistas
        emails_file (str, optional): Caminho para o arquivo de emails
    """
    errors = []
    
    if not os.path.exists(turma_a_cursistas_file):
        errors.append(f"Arquivo de cursistas não encontrado: {turma_a_cursistas_file}")
    
    if emails_file and not os.path.exists(emails_file):
        errors.append(f"Arquivo de emails não encontrado: {emails_file}")
        
    return errors

# %% [markdown]
# 3 - Carregar dados dos cursistas

# %%
# Load the cursistas dataframe
try:
    df_cursistas = pd.read_excel(turma_a_cursistas_file)    # Load the cursistas dataframes
    try:
        # Carregar Turma A
        df_cursistas_a = pd.read_excel(turma_a_cursistas_file)
        df_cursistas_a[matching_column_cursistas] = df_cursistas_a[matching_column_cursistas].astype(str).str.strip().str.lower()
        df_cursistas_a['turma'] = 'A'  # Adiciona identificador da turma
        print("Arquivo da Turma A carregado com sucesso!")
        
        # Carregar Turma B
        df_cursistas_b = pd.read_excel(turma_b_cursistas_file)
        df_cursistas_b[matching_column_cursistas] = df_cursistas_b[matching_column_cursistas].astype(str).str.strip().str.lower()
        df_cursistas_b['turma'] = 'B'  # Adiciona identificador da turma
        print("Arquivo da Turma B carregado com sucesso!")
        
        # Combinar as duas turmas em um único DataFrame
        df_cursistas = pd.concat([df_cursistas_a, df_cursistas_b], ignore_index=True)
        print(f"\nTotal de cursistas carregados: {len(df_cursistas)}")
        print(f"Turma A: {len(df_cursistas_a)} cursistas")
        print(f"Turma B: {len(df_cursistas_b)} cursistas")
        
    except FileNotFoundError as e:
        print(f"Error loading cursistas file: {e}. Make sure the file path is correct.")
        raise SystemExit(f"Error loading cursistas file: {e}. Cannot proceed.")
    except Exception as e:
        print(f"Erro inesperado ao carregar arquivos: {e}")
        raise SystemExit(f"Cannot proceed due to unexpected error: {e}")
    # Clean the matching column in df_cursistas
    df_cursistas[matching_column_cursistas] = df_cursistas[matching_column_cursistas].astype(str).str.strip().str.lower()
except FileNotFoundError as e:
    print(f"Error loading cursistas file: {e}. Make sure the file path is correct.")
    raise SystemExit(f"Error loading cursistas file: {e}. Cannot proceed.")
# Out:
# Arquivo da Turma A carregado com sucesso!
# Arquivo da Turma B carregado com sucesso!
#
# Total de cursistas carregados: 421
# Turma A: 211 cursistas
# Turma B: 210 cursistas

# %%
# Visualizar primeiras linhas do DataFrame
display(df_cursistas.head())
# Out:
#                                      [0] login  \
# 0                  claudemir-de-oliveira-filho
# 1  claudia-angelica-do-nascimento-alves-santos
# 2        claudia-nubia-lira-do-nascimento-lima
# 3            dulce-cristina-dos-santos-barbosa
# 4                     edivaldo-da-costa-pontes
#
#                            [1] Nome do usuário  \
# 0                  CLAUDEMIR DE OLIVEIRA FILHO
# 1  Cláudia Angélica do Nascimento Alves Santos
# 2        CLAUDIA NUBIA LIRA DO NASCIMENTO LIMA
# 3           Dulce Cristina dos Santos Barbosa
# 4                     Edivaldo da Costa Pontes
#
#                           [2] E-mail       [3]CPF  \
# 0  claudimirdeoliveira2017@gmail.com  80858295172
# 1        claudiaangel81.ca@gmail.com   3841221408
# 2         claudianubialira@gmail.com   3496215437
# 3            crisdulce2012@gmail.com  34476636500
# 4      edi.historia.pontes@gmail.com  65056280291
#
#   [4] Data de nascimento (opcional)  \
# 0               1973-01-31 00:00:00
# 1               1981-12-02 00:00:00
# 2               1981-02-28 00:00:00
# 3               1963-04-02 00:00:00
# 4               1976-12-07 00:00:00
#
#    [5] Senha (opcional - caso não informado, será gerado automaticamente)  \
# 0                                       8.085830e+10
# 1                                       3.841221e+09
# 2                                       3.496215e+09
# 3                                       3.447664e+10
# 4                                       6.505628e+10
#
#   [5] Função (Administrador, Professor, Tutor ou Aluno)  \
# 0                                              Aluno
# 1                                              Aluno
# 2                                              Aluno
# 3                                              Aluno
# 4                                              Aluno
#
#    Obs: e-mail que entra no meet turma
# 0                            NaN     A
# 1                            NaN     A
# 2                            NaN     A
# 3                            NaN     A
# 4                            NaN     A

# %% [markdown]
# 4 - Função de verificação de emails capturados em uma sessão do meet

# %%
def verificar_emails(df_cursistas, emails_file):
    """
    Verifica se os emails fornecidos existem na planilha de cursistas.
    
    Args:
        df_cursistas (pd.DataFrame): DataFrame com dados dos cursistas de ambas as turmas
        emails_file (str): Caminho para o arquivo com lista de emails
    """
    # Verificar existência do arquivo de emails
    if not os.path.exists(emails_file):
        print(f"Erro: Arquivo de emails não encontrado: {emails_file}")
        return
        
    try:
        # Verifica se a coluna de email existe
        if '[2] E-mail' not in df_cursistas.columns:
            print("Erro: Coluna '[2] E-mail' não encontrada na planilha de cursistas")
            return
        
        # Carrega arquivo com emails para verificar
        try:
            with open(emails_file, 'r') as f:
                emails_verificar = [email.strip().lower() for email in f.readlines() if email.strip()]
        except UnicodeDecodeError:
            print("Erro: Arquivo de emails com encoding inválido. Use UTF-8")
            return
            
        if not emails_verificar:
            print("Erro: Arquivo de emails está vazio")
            return
        
        # Converte emails dos cursistas para lowercase para comparação
        emails_cursistas = df_cursistas[['[2] E-mail', 'turma']].copy()
        emails_cursistas['[2] E-mail'] = emails_cursistas['[2] E-mail'].str.strip().str.lower()
        
        # Verifica emails
        emails_encontrados = []
        emails_nao_encontrados = []
        emails_invalidos = []
        turmas_encontradas = []
        
        for email in emails_verificar:
            if '@' not in email:
                emails_invalidos.append(email)
            else:
                # Procura o email e sua turma correspondente
                encontrado = emails_cursistas[emails_cursistas['[2] E-mail'] == email]
                if not encontrado.empty:
                    emails_encontrados.append(email)
                    turmas_encontradas.append(encontrado['turma'].iloc[0])
                else:
                    emails_nao_encontrados.append(email)

        # Exibe apenas os emails não encontrados
        if emails_nao_encontrados:
            print("\nEmails não encontrados nas Turmas A e B:")
            for email in emails_nao_encontrados:
                print(f"{email}")
        else:
            print("\nTodos os emails foram encontrados!")

        # Exibe resultados
        print("\nResultados da verificação de emails:")
        print(f"Total de emails verificados: {len(emails_verificar)}")
        print(f"Emails encontrados: {len(emails_encontrados)}")
        print(f"Emails não encontrados: {len(emails_nao_encontrados)}")
        print(f"Emails inválidos: {len(emails_invalidos)}")
        
        # if emails_nao_encontrados:
        #     print("\nEmails não encontrados na planilha:")
        #     for email in emails_nao_encontrados:
        #         print(f"{email}")  # Removed the hyphen
        
        if emails_invalidos:
            print("\nEmails com formato inválido:")
            for email in emails_invalidos:
                print(f"- {email}")
        
        if emails_encontrados:
            print("\nEmails encontrados (com suas turmas):")
            for email, turma in zip(emails_encontrados, turmas_encontradas):
                print(f"Turma {turma}: {email}")
                
    except pd.errors.EmptyDataError:
        print("Erro: A planilha de cursistas está vazia")
    except Exception as e:
        print(f"Erro inesperado: {e}")

# %% [markdown]
# 5 - Execução da verificação

# %%
# Exemplo de uso da função atualizada
verificar_emails(
    df_cursistas,  # DataFrame unificado com ambas as turmas
    '/home/emanoel/Downloads/avamec_inscricoes/emails_verificar.txt'
)
# Out:
# Emails não encontrados nas Turmas A e B:
# anakatia.fn@hotmail.com
# adrianamadja@gmail.com
# alexsantana7@gmail.com
# heidyani@gmail.com
# karla.lopes@ufc.br
# karlacristiner@ufc.br
# marques2022ufc@gmail.com
# sumarafrotadn@gmail.com
# vitoriaramos@ufc.br
# vsalesp4@gmail.com
#
# Resultados da verificação de emails:
# Total de emails verificados: 207
# Emails encontrados: 197
# Emails não encontrados: 10
# Emails inválidos: 0
#
# Emails encontrados (com suas turmas):
# Turma A: accacia.vicente@gmail.com
# Turma A: adjuntosemed025@gmail.com
# Turma A: aedyggomes@gmail.com
# Turma A: albuquerquenagela@gmail.com
# Turma A: alexandrabraga02@gmail.com
# Turma A: alexsandracavalcanti531@gmail.com
# Turma A: alinenunesje@gmail.com
# Turma A: ambrosinasilva2605@gmail.com
# Turma A: ana.bacelar@educaita.com.br
# Turma A: anamariabarbaralima436@gmail.com
# Turma A: andreia05nogueira@gmail.com
# Turma A: ang.roarelli@gmail.com
# Turma A: aparecidooliveiratrindade93@gmail.com
# Turma A: apfqueiroz@yahoo.com.br
# Turma A: balbe02.liliane@gmail.com
# Turma A: bamcienciassociais@gmail.com
# Turma A: belabarcelos2020@gmail.com
# Turma A: bezerracristina425@gmail.com
# Turma A: brasilkelly456@gmail.com
# Turma A: canejoamanda02@gmail.com
# Turma A: carvalhokatia395@gmail.com
# Turma A: ceciliakelmadirecao21@gmail.com
# Turma A: celileitetorres@gmail.com
# Turma A: claudete.siqueira@upe.br
# Turma A: claudiaangel81.ca@gmail.com
# Turma A: claudiamdsilva48@gmail.com
# Turma A: claudianubialira@gmail.com
# Turma A: claudimirdeoliveira2017@gmail.com
# Turma A: cleidemaciel00@gmail.com
# Turma A: coord.julianabastos@gmail.com
# Turma A: coordedupk@gmail.com
# Turma A: crisdulce2012@gmail.com
# Turma A: criska1712@gmail.com
# Turma A: cristianeferreira28@icloud.com
# Turma A: cristina22rs@gmail.com
# Turma A: csoraya980@gmail.com
# Turma A: darcilenemendes@gmail.com
# Turma A: deboraregina8364@gmail.com
# Turma A: deborartes66@gmail.com
# Turma A: decaangelicamari@gmail.com
# Turma A: deiapascoadirecao@gmail.com
# Turma A: deusenildeb@gmail.com
# Turma A: dhionico22@gmail.com
# Turma A: dicabenites2021@gmail.com
# Turma A: dionatanmendesmedeiros@gmail.com
# Turma A: diretorapatriciafarias@gmail.com
# Turma A: dorinhacr2017@gmail.com
# Turma A: dutra.luziane@gmail.com
# Turma A: edi.historia.pontes@gmail.com
# Turma A: edileneprofessorasim@gmail.com
# Turma A: ednei4655@gmail.com
# Turma A: educadorcarloseduardo@gmail.com
# Turma A: egledepaula007@gmail.com
# Turma A: elaene.bras@gmail.com
# Turma A: elianemachado4143@gmail.com
# Turma A: elzalimiroamorim@gmail.com
# Turma A: emeikeniasetti43177816@edu.carazinho.rs.gov.br
# Turma A: enfreitas2021@gmail.com
# Turma A: eraldina9394luz@gmail.com
# Turma A: erikacoache2016@gmail.com
# Turma A: eunice6moreira@gmail.com
# Turma A: evaeducadora1906@gmail.com
# Turma A: evandrofroes2014@gmail.com
# Turma A: fabianadgomes26@gmail.com
# Turma A: fabianafabialbuquerque@gmail.com
# Turma A: fabiojf.fernandes@gmail.com
# Turma A: fabriciacicaferreira@gmail.com
# Turma A: fatima13liz15@gmail.com
# Turma A: flaviagasparoti@gmail.com
# Turma A: francelinaduarte14@gmail.com
# Turma A: franciele_tatsch@edu.carazinho.rs.gov.br
# Turma A: francielle.castro@edu.patosdeminas.mg.gov.br
# Turma A: genyhatempirapora@gmail.com
# Turma A: georgiaspinelli1980@gmail.com
# Turma A: gi.jaque.pimentel@gmail.com
# Turma A: gildadaisy@gmail.com
# Turma A: gilvanilson12@gmail.com
# Turma A: giscely_samarah@hotmail.com
# Turma A: gislener308@gmail.com
# Turma A: grazioliveirarocha@gmail.com
# Turma A: hutovera624@gmail.com
# Turma A: ilmagalvao2024@gmail.com
# Turma A: irisfigueiroacardoso@gmail.com
# Turma A: isaiasbrazdealmeidajunior.juni@gmail.com
# Turma A: jac.miranda2018@gmail.com
# Turma A: jazaniascs@gmail.com
# Turma A: jeannie.luz@educaita.com.br
# Turma A: jmsouza88@gmail.com
# Turma A: josedantasguimaraesdasilva3@gmail.com
# Turma A: josefaclotildesd@gmail.com
# Turma A: josianegenaro@gmail.com
# Turma A: josieldapereira3@gmail.com
# Turma A: jotinhafrancisco@gmail.com
# Turma A: jpereiracorrea@gmail.com
# Turma A: jucimaraboia08@gmail.com
# Turma A: julianaapschneider@gmail.com
# Turma A: julianadalpra20@gmail.com
# Turma A: julianamorellato3@gmail.com
# Turma A: jussaratavares1012@gmail.com
# Turma A: karlaeducacristina@gmail.com
# Turma A: katia.kssy31@gmail.com
# Turma A: katiaddanilo@gmail.com
# Turma A: kgomesdeoliveira4@gmail.com
# Turma A: larissa.barbosa@educaita.com.br
# Turma A: larissasjeld@gmail.com
# Turma A: leilalailavifelipe@gmail.com
# Turma A: leilaleoncios@gmail.com
# Turma A: leonice.batista@gmail.com
# Turma A: lilian.insinio@educaita.com.br
# Turma A: liliana32bk@gmail.com
# Turma A: liliangocosta@gmail.com
# Turma A: lis.barroso@gmail.com
# Turma A: lizaldetesouzaviana@gmail.com
# Turma A: luchalubaguiar@gmail.com
# Turma A: luciane.felicio123@gmail.com
# Turma A: luciarasousasje@gmail.com
# Turma A: luciene.cec.2022@gmail.com
# Turma A: lucimeire.lemes@portoesperidiao.edu.mt.gov.br
# Turma A: lulu.pedagogo94@gmail.com
# Turma A: lupurcino09@gmail.com
# Turma A: luziamariaoliveiramariano@gmail.com
# Turma A: lygia.eulerrocha@gmail.com
# Turma A: mainarapaquesdirecao@gmail.com
# Turma A: malryraimunda123@gmail.com
# Turma A: marcellyalysson@gmail.com
# Turma A: marcia_monteiro@edu.carazinho.rs.gov.br
# Turma A: marcieti.quindeler@gmail.com
# Turma A: mariaepaulohenrique28@gmail.com
# Turma A: mariajoseanelimasilva@gmail.com
# Turma A: mariarosevane0@gmail.com
# Turma A: maristeladarosasc@gmail.com
# Turma A: marlene.cecmf@gmail.com
# Turma A: marsuelebarbosa@gmail.com
# Turma A: martaalvesisaac123@gmail.com
# Turma A: marylindadejesus@hotmail.com
# Turma A: marymaisesporte@gmail.com
# Turma A: maurarodrigues.pedag@gmail.com
# Turma A: mauroregis43@gmail.com
# Turma A: meri29bage@gmail.com
# Turma A: mgfloliveira@gmail.com
# Turma A: millejal78@gmail.com
# Turma A: mirianadrianabastos@gmail.com
# Turma A: mirianbborges@hotmail.com
# Turma A: ms8265160@gmail.com
# Turma A: muniziafraga@gmail.com
# Turma A: neiacarla1410@gmail.com
# Turma A: neilamoraescarvalho@gmail.com
# Turma A: nidallamarta@gmail.com
# Turma A: nilza.silva@educaita.com.br
# Turma A: oliveiramateus540@gmail.com
# Turma A: oziane.ol@gmail.com
# Turma A: patricia.azimonte@educaita.com.br
# Turma A: pedagoga.renataap@gmail.com
# Turma A: pereiradealmeidacastrolyllyans@gmail.com
# Turma A: pereiradeoliveiracicera3@gmail.com
# Turma A: priscila.escolaaparecida@gmail.com
# Turma A: professoralternan@gmail.com
# Turma A: profs.lolo2010@gmail.com
# Turma A: rafaelaraelamancio@gmail.com
# Turma A: ramelowjoseline@gmail.com
# Turma A: regilenem58@gmail.com
# Turma A: renata.galdino@educaita.com.br
# Turma A: ricardotito670@gmail.com
# Turma A: roliveirabercan@gmail.com
# Turma A: rosaangelamotta@gmail.com
# Turma A: rosaccamp@gmail.com
# Turma A: rosangelaalanna@gmail.com
# Turma A: rosicleideramiro21@gmail.com
# Turma A: rosielenraitz@gmail.com
# Turma A: rvera7264@gmail.com
# Turma A: sandraregis.veloso@gmail.com
# Turma A: sccristo01@gmail.com
# Turma A: secretaria-preussler@edu.saoluizgonzaga.rs.gov.br
# Turma A: selma_soaresdasilva@yahoo.com.br
# Turma A: semed.elietecristina@gmail.com
# Turma A: sheylaferreira40@gmail.com
# Turma A: silvaarno231@gmail.com
# Turma A: silvialimaufal@gmail.com
# Turma A: silviamartamartins@gmail.com
# Turma A: simone_deabreu@edu.carazinho.rs.gov.br
# Turma A: simonemgga@gmail.com
# Turma A: socorroclaudino@prof.seducsm.com.br
# Turma A: socorromfernandes732@gmail.com
# Turma A: solchris98@gmail.com
# Turma A: tatiane.diretorescolar@gmail.com
# Turma A: tatymarquesdalri@gmail.com
# Turma A: valdineia._.nf@hotmail.com
# Turma A: vanesaarantes@gmail.com
# Turma A: vaninhasantana2023@gmail.com
# Turma A: veraschmitzlucia@gmail.com
# Turma A: vivirocha.filhos@gmail.com
# Turma A: weilaedneyluciana@gmail.com
# Turma A: wilzamaria07@gmail.com
# Turma A: zaganellimarimluciana@gmail.com
# Turma A: zicanolasco@gmail.com
# Turma A: tiafada.23@hotmail.com
# Turma A: katiajeilson@gmail.com
