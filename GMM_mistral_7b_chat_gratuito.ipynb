# %% [markdown]
# Vamos examinar o conteúdo do dataset sintético:

# %%
import pandas as pd

# Carregar o arquivo CSV enviado pelo usuário
file_path = '/content/drive/MyDrive/mestrado/Emanoel/Datasets/dataset_sintetico.csv'
data = pd.read_csv(file_path)

# Exibir as primeiras linhas do dataset para entender sua estrutura
data.head()
# Out:
#      Aluno  Números Inteiros  Frações  Equações  Geometria Básica  Funções  \
# 0  Aluno_1               4.1      8.7       9.4               6.4      3.0
# 1  Aluno_2               3.4      6.9       9.1               7.8      3.1
# 2  Aluno_3               8.5      9.4       4.2               3.8      3.1
# 3  Aluno_4               5.9      5.4       5.5               7.3      9.2
# 4  Aluno_5               5.0      5.2       7.9               7.7      6.1
#
#    Trigonometria  Probabilidade  Estatística
# 0            6.6            7.2          8.8
# 1            4.2            6.4          4.9
# 2            4.0            7.4          6.4
# 3            6.6            5.1          7.4
# 4            7.5            3.0          7.2

# %% [markdown]
# O dataset enviado contém informações sobre o desempenho de alunos em diferentes tópicos de matemática, como números inteiros, frações, equações, geometria básica, funções, trigonometria, probabilidade e estatística.
# Próximos Passos:
#
# * Identificar Chaves Comuns: Encontrar colunas que possam servir como chaves para unificação, como IDs de alunos ou timestamps.
#
# * Normalização de Dados: Garantir que os dados estejam em formatos compatíveis para unificação.
#
# * Ferramentas de Análise: Utilizar ferramentas de análise de dados para explorar e visualizar os dados unificados.

# %%
# Carregar o arquivo CSV do UCI
file_path_uci = '/content/drive/MyDrive/mestrado/Emanoel/Datasets/cortez/student-mat.csv'
data_uci = pd.read_csv(file_path_uci, sep=';')

# Exibir as primeiras linhas do dataset UCI para entender sua estrutura
data_uci.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %% [markdown]
# O dataset UCI carregado contém informações detalhadas sobre alunos, incluindo atributos como escola, sexo, idade, endereço, tamanho da família, status dos pais, educação dos pais, empregos dos pais, entre outros. Além disso, inclui notas (G1, G2, G3) que representam o desempenho acadêmico dos alunos em diferentes períodos.
# Possíveis Chaves para Unificação:
#
# * Idade (age): Pode ser usada para alinhar dados de desempenho em matemática com dados demográficos.
#
# * Notas (G1, G2, G3): Podem ser comparadas ou combinadas com as notas de desempenho em matemática do primeiro dataset.
#
# Próximos Passos:
#
# * Normalização de Dados: Certificar-se de que os formatos de dados são consistentes entre os datasets.
#
# * Combinação de Dados: Usar chaves comuns para unir os datasets e criar um conjunto de dados unificado.

# %% [markdown]
# Vamos prosseguir com a unificação dos dados com base nas colunas relevantes. Primeiro, precisamos identificar colunas que possam ser usadas como chaves para unir os datasets. Vamos explorar isso.

# %%
# Verificar colunas em ambos os datasets para identificar possíveis chaves de unificação
columns_sintetico = data.columns
columns_uci = data_uci.columns

columns_sintetico, columns_uci
# Out:
# (Index(['Aluno', 'Números Inteiros', 'Frações', 'Equações', 'Geometria Básica',
#         'Funções', 'Trigonometria', 'Probabilidade', 'Estatística'],
#        dtype='object'),
#  Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#         'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#         'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#         'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#         'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#        dtype='object'))

# %% [markdown]
# Os datasets possuem estruturas diferentes, e não há colunas óbvias que possam ser usadas diretamente como chaves para unificação. No entanto, podemos considerar algumas abordagens para unificação:
#
# * Criação de Chaves Artificiais: Se ambos os datasets contiverem informações sobre os mesmos alunos, poderíamos criar uma chave artificial baseada em características comuns, como idade, sexo, ou desempenho em disciplinas específicas.
#
# * Análise de Dados Complementares: Se os datasets contiverem informações complementares (por exemplo, um com desempenho em matemática e outro com informações demográficas), poderíamos unificá-los com base em análises estatísticas ou de aprendizado de máquina.
#
# * Normalização de Dados: Ajustar os dados para que tenham formatos e escalas similares, facilitando a comparação e unificação.
#
# Próximos Passos:
#
# * Explorar Dados: Analisar mais profundamente ambos os datasets para identificar possíveis relações ou padrões.
#
# * Transformação de Dados: Aplicar transformações necessárias para facilitar a unificação.

# %% [markdown]
# Para realizar uma análise de dados complementares entre os dois datasets, podemos seguir os seguintes passos:
#
# * Identificar Colunas Relevantes: Selecionar colunas de ambos os datasets que possam fornecer insights complementares. Por exemplo, podemos comparar o desempenho em matemática com informações demográficas ou hábitos de estudo.
#
# * Análise Estatística: Realizar análises estatísticas para identificar correlações ou padrões entre as variáveis dos dois datasets.
#
# * Visualização de Dados: Criar visualizações para facilitar a compreensão das relações entre os dados.
#
# Vamos começar identificando algumas colunas relevantes em ambos os datasets e realizar uma análise inicial.

# %%
# Selecionar colunas relevantes de ambos os datasets
# Dataset Sintético: Desempenho em matemática
math_performance = data.set_index('Aluno')

# Dataset UCI: Informações demográficas e desempenho geral
demographic_info = data_uci[['sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu', 'studytime', 'failures', 'G1', 'G2', 'G3']]

# Exibir as primeiras linhas das colunas selecionadas
math_performance.head(), demographic_info.head()
# Out:
# (         Números Inteiros  Frações  Equações  Geometria Básica  Funções  \
#  Aluno
#  Aluno_1               4.1      8.7       9.4               6.4      3.0
#  Aluno_2               3.4      6.9       9.1               7.8      3.1
#  Aluno_3               8.5      9.4       4.2               3.8      3.1
#  Aluno_4               5.9      5.4       5.5               7.3      9.2
#  Aluno_5               5.0      5.2       7.9               7.7      6.1
#
#           Trigonometria  Probabilidade  Estatística
#  Aluno
#  Aluno_1            6.6            7.2          8.8
#  Aluno_2            4.2            6.4          4.9
#  Aluno_3            4.0            7.4          6.4
#  Aluno_4            6.6            5.1          7.4
#  Aluno_5            7.5            3.0          7.2  ,
#    sex  age address famsize Pstatus  Medu  Fedu  studytime  failures  G1  G2  \
#  0   F   18       U     GT3       A     4     4          2         0   5   6
# ...

# %% [markdown]
# A análise de dados complementares entre os dois datasets revela que:
#
# * Dataset Sintético: Contém informações detalhadas sobre o desempenho de alunos em diferentes tópicos de matemática, como números inteiros, frações, equações, geometria básica, funções, trigonometria, probabilidade e estatística.
#
# * Dataset UCI: Fornece informações demográficas e de desempenho geral dos alunos, incluindo sexo, idade, endereço, tamanho da família, status de coabitação dos pais, educação dos pais, tempo de estudo, falhas anteriores e notas gerais (G1, G2, G3).
#
# Análise Complementar:
#
# * Desempenho em Matemática vs. Informações Demográficas: Podemos explorar como fatores demográficos (como idade, sexo, educação dos pais) influenciam o desempenho em matemática.
#
# * Tempo de Estudo e Desempenho: Analisar como o tempo de estudo afeta o desempenho em diferentes tópicos de matemática.
#
# * Notas Gerais vs. Desempenho em Matemática: Comparar as notas gerais (G1, G2, G3) com o desempenho em matemática para identificar correlações.
#
# Próximos Passos:
#
# * Análise Estatística: Realizar análises estatísticas para identificar correlações e padrões entre os dados demográficos e o desempenho em matemática.
#
# * Visualização de Dados: Criar visualizações para melhor entender as relações entre as variáveis.

# %% [markdown]
# # O terceiro dataset - OULAD

# %% [markdown]
# Vamos começar explorando a estrutura desses arquivos para entender como podemos integrá-los com os outros datasets que já analisamos.
#
# Vamos carregar e inspecionar cada um dos arquivos para identificar as informações contidas neles.

# %%
# Carregar os arquivos CSV do OULAD
file_paths_oulad = [
    '/content/drive/MyDrive/mestrado/Emanoel/Datasets/oulad/studentInfo.csv',
    '/content/drive/MyDrive/mestrado/Emanoel/Datasets/oulad/courses.csv',
    '/content/drive/MyDrive/mestrado/Emanoel/Datasets/oulad/assessments.csv',
    '/content/drive/MyDrive/mestrado/Emanoel/Datasets/oulad/studentRegistration.csv',
    '/content/drive/MyDrive/mestrado/Emanoel/Datasets/oulad/studentAssessment.csv',
    '/content/drive/MyDrive/mestrado/Emanoel/Datasets/oulad/vle.csv',
    '/content/drive/MyDrive/mestrado/Emanoel/Datasets/oulad/studentVle.csv'
]

# Carregar cada arquivo e exibir as primeiras linhas para entender sua estrutura
data_oulad = {file.split('.')[0]: pd.read_csv(file) for file in file_paths_oulad}

# Exibir as primeiras linhas de cada dataset
{name: df.head() for name, df in data_oulad.items()}
# Out:
# {'/content/drive/MyDrive/mestrado/Emanoel/Datasets/oulad/studentInfo':   code_module code_presentation  id_student gender                region  \
#  0         AAA             2013J       11391      M   East Anglian Region
#  1         AAA             2013J       28400      F              Scotland
#  2         AAA             2013J       30268      F  North Western Region
#  3         AAA             2013J       31604      F     South East Region
#  4         AAA             2013J       32885      F  West Midlands Region
#
#         highest_education imd_band age_band  num_of_prev_attempts  \
#  0       HE Qualification  90-100%     55<=                     0
#  1       HE Qualification   20-30%    35-55                     0
#  2  A Level or Equivalent   30-40%    35-55                     0
#  3  A Level or Equivalent   50-60%    35-55                     0
#  4     Lower Than A Level   50-60%     0-35                     0
#
#     studied_credits disability final_result
# ...

# %% [markdown]
# O dataset OULAD consiste em vários arquivos CSV, cada um contendo diferentes tipos de informações sobre cursos, alunos, avaliações e interações com ambientes virtuais de aprendizagem. Aqui está um resumo de cada arquivo:
#
# * studentInfo.csv: Contém informações sobre os alunos, incluindo gênero, região, nível de educação, faixa etária, créditos estudados, deficiência e resultado final.
#
# * courses.csv: Fornece informações sobre os cursos, incluindo o código do módulo, apresentação do código e duração da apresentação do módulo.
#
# * assessments.csv: Inclui detalhes sobre as avaliações, como tipo de avaliação, data e peso.
#
# * studentRegistration.csv: Registra informações sobre a inscrição dos alunos, incluindo datas de registro e cancelamento de registro.
#
# * studentAssessment.csv: Contém dados sobre as avaliações dos alunos, incluindo datas de envio e pontuações.
#
# * vle.csv: Fornece informações sobre os ambientes virtuais de aprendizagem, incluindo tipos de atividades e semanas de disponibilidade.
#
# * studentVle.csv:
#
# Análise Complementar:
#
# Com esses datasets, podemos explorar várias dimensões:
#
# * Desempenho do Aluno: Analisar como os alunos performam em diferentes avaliações e como isso se relaciona com suas informações demográficas e de registro.
#
# * Interações com VLE: Explorar como os alunos interagem com os ambientes virtuais de aprendizagem e como isso afeta seu desempenho.
#
# * Cursos e Avaliações: Analisar a estrutura dos cursos e como diferentes tipos de avaliações impactam o desempenho dos alunos.
#
# Próximos Passos:
#
# * Integração de Dados: Unificar os dados dos três datasets (Sintético, UCI e OULAD) para uma análise abrangente.
#
# * Análise Estatística e Visualização: Realizar análises estatísticas e criar visualizações para identificar padrões e insights.

# %% [markdown]
# PROMPT: A união dos datasets deve manter a significância dos dados e o sintético será a base. O dataset resultante será o input de um sistema de identificação de dificuldades de aprendizagem acadêmica.

# %% [markdown]
# Para unificar os datasets mantendo a significância dos dados e usando o dataset sintético como base, podemos seguir os seguintes passos:
#
# * Identificar Chaves Comuns: Encontrar colunas que possam servir como chaves para unificação, como IDs de alunos ou características demográficas.
#
# * Normalização de Dados: Garantir que os dados estejam em formatos compatíveis para unificação.
#
# * Integração de Dados: Combinar os dados dos três datasets (Sintético, UCI e OULAD) de forma a preservar a integridade e a significância das informações.
#
# * Análise e Visualização: Realizar análises estatísticas e criar visualizações para identificar padrões e insights.
#
# Vamos começar identificando as chaves comuns e normalizando os dados. Em seguida, procederemos com a unificação.

# %%
# Normalizar nomes de colunas para facilitar a unificação
data.columns = [col.lower().replace(' ', '_') for col in data.columns]
data_uci.columns = [col.lower().replace(' ', '_') for col in data_uci.columns]

# Adicionar um prefixo para identificar a origem dos dados
data = data.add_prefix('sintetico_')
data_uci = data_uci.add_prefix('uci_')

# Exibir as primeiras linhas dos datasets normalizados
data.head(), data_uci.head()
# Out:
# (  sintetico_aluno  sintetico_números_inteiros  sintetico_frações  \
#  0         Aluno_1                         4.1                8.7
#  1         Aluno_2                         3.4                6.9
#  2         Aluno_3                         8.5                9.4
#  3         Aluno_4                         5.9                5.4
#  4         Aluno_5                         5.0                5.2
#
#     sintetico_equações  sintetico_geometria_básica  sintetico_funções  \
#  0                 9.4                         6.4                3.0
#  1                 9.1                         7.8                3.1
#  2                 4.2                         3.8                3.1
#  3                 5.5                         7.3                9.2
#  4                 7.9                         7.7                6.1
#
#     sintetico_trigonometria  sintetico_probabilidade  sintetico_estatística
# ...

# %% [markdown]
# Os datasets foram normalizados e preparados para unificação, mantendo a significância dos dados e utilizando o dataset sintético como base. Aqui está um resumo das etapas realizadas:
#
# * Normalização de Nomes de Colunas: Os nomes das colunas foram convertidos para minúsculas e espaços foram substituídos por underscores para facilitar a unificação.
#
# * Adição de Prefixos: Prefixos foram adicionados para identificar a origem dos dados (sintetico_ para o dataset sintético e uci_ para o dataset UCI).
#
# Próximos Passos para Unificação:
#
# * Identificação de Chaves Comuns: Identificar colunas que possam servir como chaves para unificação, como IDs de alunos ou características demográficas.
#
# * Integração com OULAD: Incorporar dados relevantes do OULAD, como informações de cursos, avaliações e interações com ambientes virtuais de aprendizagem.
#
# * Análise e Visualização: Realizar análises estatísticas e criar visualizações para identificar padrões e insights que possam ser úteis para o sistema de identificação de dificuldades de aprendizagem acadêmica.

# %% [markdown]
# Para identificar chaves comuns que possam ser usadas para unificar os datasets, precisamos examinar as colunas em cada dataset e procurar por colunas que possam representar identificadores únicos ou características que possam ser usadas para combinar os dados.
#
# Vamos examinar as colunas dos datasets sintético, UCI e OULAD para identificar possíveis chaves comuns.

# %%
# Exibir as colunas de cada dataset para identificar possíveis chaves comuns
columns_sintetico = data.columns
columns_uci = data_uci.columns
columns_oulad = {name: df.columns.tolist() for name, df in data_oulad.items()}

columns_sintetico, columns_uci, columns_oulad
# Out:
# (Index(['sintetico_aluno', 'sintetico_números_inteiros', 'sintetico_frações',
#         'sintetico_equações', 'sintetico_geometria_básica', 'sintetico_funções',
#         'sintetico_trigonometria', 'sintetico_probabilidade',
#         'sintetico_estatística'],
#        dtype='object'),
#  Index(['uci_school', 'uci_sex', 'uci_age', 'uci_address', 'uci_famsize',
#         'uci_pstatus', 'uci_medu', 'uci_fedu', 'uci_mjob', 'uci_fjob',
#         'uci_reason', 'uci_guardian', 'uci_traveltime', 'uci_studytime',
#         'uci_failures', 'uci_schoolsup', 'uci_famsup', 'uci_paid',
#         'uci_activities', 'uci_nursery', 'uci_higher', 'uci_internet',
#         'uci_romantic', 'uci_famrel', 'uci_freetime', 'uci_goout', 'uci_dalc',
#         'uci_walc', 'uci_health', 'uci_absences', 'uci_g1', 'uci_g2', 'uci_g3'],
#        dtype='object'),
#  {'/content/drive/MyDrive/mestrado/Emanoel/Datasets/oulad/studentInfo': ['code_module',
#    'code_presentation',
#    'id_student',
#    'gender',
# ...

# %% [markdown]
# Identificação de Chaves Comuns:
#
# * Dataset Sintético: As colunas incluem informações sobre alunos e desempenho em matemática. Uma possível chave comum poderia ser um identificador de aluno, como sintetico_aluno.
#
# * Dataset UCI: As colunas incluem informações demográficas e de desempenho geral. Uma possível chave comum poderia ser um identificador de aluno, se disponível, ou características demográficas como idade (uci_age) e sexo (uci_sex).
#
# * Dataset OULAD: As colunas incluem informações sobre cursos, avaliações e interações com ambientes virtuais de aprendizagem. Possíveis chaves comuns poderiam ser id_student em studentInfo.csv ou studentRegistration.csv.
#
# Próximos Passos:
#
# * Comparar Colunas: Compare as colunas de cada dataset para identificar colunas que possam servir como chaves comuns.
#
# * Transformação de Dados: Se necessário, transforme os dados para criar chaves comuns, como concatenar colunas ou criar novas colunas baseadas em características existentes.

# %% [markdown]
# Para comparar as colunas dos datasets e identificar possíveis chaves comuns, você pode seguir estas etapas:
# Dataset Sintético:
#
#     sintetico_aluno: Identificador do aluno.
#     sintetico_números_inteiros: Desempenho em números inteiros.
#     sintetico_frações: Desempenho em frações.
#     sintetico_equações: Desempenho em equações.
#     sintetico_geometria_básica: Desempenho em geometria básica.
#     sintetico_funções: Desempenho em funções.
#     sintetico_trigonometria: Desempenho em trigonometria.
#     sintetico_probabilidade: Desempenho em probabilidade.
#     sintetico_estatística: Desempenho em estatística.
#
# Dataset UCI:
#
#     uci_school: Escola do aluno.
#     uci_sex: Sexo do aluno.
#     uci_age: Idade do aluno.
#     uci_address: Endereço do aluno.
#     uci_famsize: Tamanho da família.
#     uci_pstatus: Status de coabitação dos pais.
#     uci_medu: Educação da mãe.
#     uci_fedu: Educação do pai.
#     uci_mjob: Trabalho da mãe.
#     uci_fjob: Trabalho do pai.
#     uci_reason: Razão para escolher a escola.
#     uci_guardian: Guardião do aluno.
#     uci_traveltime: Tempo de viagem para a escola.
#     uci_studytime: Tempo de estudo.
#     uci_failures: Número de falhas.
#     uci_schoolsup: Suporte escolar.
#     uci_famsup: Suporte familiar.
#     uci_paid: Aulas pagas.
#     uci_activities: Atividades extracurriculares.
#     uci_nursery: Frequentou creche.
#     uci_higher: Deseja ensino superior.
#     uci_internet: Acesso à internet.
#     uci_romantic: Relacionamento romântico.
#     uci_famrel: Qualidade do relacionamento familiar.
#     uci_freetime: Tempo livre.
#     uci_goout: Saídas com amigos.
#     uci_dalc: Consumo de álcool durante a semana.
#     uci_walc: Consumo de álcool no fim de semana.
#     uci_health: Status de saúde.
#     uci_absences: Número de ausências.
#     uci_g1: Nota do primeiro período.
#     uci_g2: Nota do segundo período.
#     uci_g3: Nota final.
#
# Dataset OULAD:
#
#     studentInfo.csv:
#         code_module: Código do módulo.
#         code_presentation: Código da apresentação.
#         id_student: Identificador do aluno.
#         gender: Gênero do aluno.
#         region: Região do aluno.
#         highest_education: Maior nível de educação.
#         imd_band: Faixa de IMD.
#         age_band: Faixa etária.
#         num_of_prev_attempts: Número de tentativas anteriores.
#         studied_credits: Créditos estudados.
#         disability: Deficiência.
#         final_result: Resultado final.
#
#     courses.csv:
#         code_module: Código do módulo.
#         code_presentation: Código da apresentação.
#         module_presentation_length: Duração da apresentação do módulo.
#
#     assessments.csv:
#         code_module: Código do módulo.
#         code_presentation: Código da apresentação.
#         id_assessment: Identificador da avaliação.
#         assessment_type: Tipo de avaliação.
#         date: Data da avaliação.
#         weight: Peso da avaliação.
#
#     studentRegistration.csv:
#         code_module: Código do módulo.
#         code_presentation: Código da apresentação.
#         id_student: Identificador do aluno.
#         date_registration: Data de registro.
#         date_unregistration: Data de cancelamento de registro.
#
#     studentAssessment.csv:
#         id_assessment: Identificador da avaliação.
#         id_student: Identificador do aluno.
#         date_submitted: Data de envio.
#         is_banked: Se a avaliação foi bancada.
#         score: Pontuação.
#
#     vle.csv:
#         id_site: Identificador do site.
#         code_module: Código do módulo.
#         code_presentation: Código da apresentação.
#         activity_type: Tipo de atividade.
#         week_from: Semana de início.
#         week_to: Semana de término.
#
# Possíveis Chaves Comuns:
#
#     Identificador do Aluno: sintetico_aluno (Dataset Sintético) e id_student (Dataset OULAD).
#     Idade: uci_age (Dataset UCI) e age_band (Dataset OULAD).
#     Sexo/Gênero: uci_sex (Dataset UCI) e gender (Dataset OULAD).
#
# Essas colunas podem ser usadas para unificar os datasets, permitindo uma análise mais abrangente e integrada.

# %% [markdown]
# Para unificar os datasets e criar um conjunto de dados integrado que possa ser usado como entrada para um sistema de identificação de dificuldades de aprendizagem acadêmica, algumas transformações de dados serão necessárias. Aqui estão algumas sugestões:
# 1. Normalização de Identificadores de Alunos:
#
#     Dataset Sintético: Certifique-se de que sintetico_aluno seja um identificador único e consistente.
#     Dataset OULAD: Use id_student como identificador único.
#     Transformação: Criar uma coluna de identificador de aluno unificada que possa ser usada em todos os datasets.
#
# 2. Normalização de Idade:
#
#     Dataset UCI: uci_age está em anos.
#     Dataset OULAD: age_band está em faixas etárias.
#     Transformação: Converter age_band em uma idade média ou usar a faixa etária como uma categoria.
#
# 3. Normalização de Sexo/Gênero:
#
#     Dataset UCI: uci_sex (M/F).
#     Dataset OULAD: gender (M/F).
#     Transformação: Certificar-se de que ambos usem a mesma codificação (por exemplo, M para masculino e F para feminino).
#
# 4. Normalização de Desempenho Acadêmico:
#
#     Dataset Sintético: Desempenho em diferentes tópicos de matemática.
#     Dataset UCI: Notas gerais (uci_g1, uci_g2, uci_g3).
#     Dataset OULAD: Pontuações de avaliações (score).
#     Transformação: Normalizar as escalas de pontuação para que possam ser comparadas diretamente.
#
# 5. Criação de Chaves Comuns:
#
#     Transformação: Criar uma chave comum que combine informações de identificação de alunos, idade e gênero para facilitar a unificação.
#
# 6. Integração de Dados de Cursos e Avaliações:
#
#     Dataset OULAD: Incluir informações de cursos (code_module, code_presentation) e avaliações (id_assessment, assessment_type).
#     Transformação: Adicionar colunas para incluir informações de cursos e avaliações no dataset unificado.
#
# 7. Tratamento de Valores Ausentes:
#
#     Transformação: Preencher ou remover valores ausentes para garantir a consistência dos dados.
#
# 8. Conversão de Tipos de Dados:
#
#     Transformação: Certificar-se de que todos os dados estejam no formato correto (por exemplo, datas no formato datetime, números como floats ou integers).

# %%
# Exemplo de normalização de idade
def normalize_age(age_band):
    age_mapping = {
        '0-35': 18,
        '35-55': 45,
        '55<=': 60
    }
    # Use the correct key to access the studentInfo DataFrame
    return age_mapping.get(age_band, 45)  # Valor padrão

# Use the correct key to access the studentInfo DataFrame
data_oulad['/content/drive/MyDrive/mestrado/Emanoel/Datasets/oulad/studentInfo']['age'] = data_oulad['/content/drive/MyDrive/mestrado/Emanoel/Datasets/oulad/studentInfo']['age_band'].apply(normalize_age)

# Exemplo de unificação de identificadores de alunos
data['unified_id'] = data['sintetico_aluno']
data_uci['unified_id'] = data_uci['uci_school'] + '_' + data_uci['uci_sex'] + '_' + data_uci['uci_age'].astype(str)
# Use the correct key to access the studentInfo DataFrame
data_oulad['/content/drive/MyDrive/mestrado/Emanoel/Datasets/oulad/studentInfo']['unified_id'] = data_oulad['/content/drive/MyDrive/mestrado/Emanoel/Datasets/oulad/studentInfo']['id_student']

# Exemplo de normalização de gênero
data_uci['uci_sex'] = data_uci['uci_sex'].map({'F': 'Female', 'M': 'Male'})
# Use the correct key to access the studentInfo DataFrame
data_oulad['/content/drive/MyDrive/mestrado/Emanoel/Datasets/oulad/studentInfo']['gender'] = data_oulad['/content/drive/MyDrive/mestrado/Emanoel/Datasets/oulad/studentInfo']['gender'].map({'F': 'Female', 'M': 'Male'})

# %% [markdown]
# Para implementar as transformações sugeridas, podemos seguir os passos abaixo. Vou mostrar como você pode realizar essas transformações usando Python e a biblioteca pandas. Vamos focar nas transformações de normalização de identificadores de alunos, idade, sexo/gênero e desempenho acadêmico.

# %% [markdown]
# ## Normalização de identificadores de alunos

# %%
# Adicionar uma coluna de identificador unificado
data['unified_id'] = data['sintetico_aluno']
data_uci['unified_id'] = data_uci['uci_school'] + '_' + data_uci['uci_sex'] + '_' + data_uci['uci_age'].astype(str)
# Use the correct key to access the studentInfo DataFrame
data_oulad['/content/drive/MyDrive/mestrado/Emanoel/Datasets/oulad/studentInfo']['unified_id'] = data_oulad['/content/drive/MyDrive/mestrado/Emanoel/Datasets/oulad/studentInfo']['id_student']

# %% [markdown]
# ## Normalização de idade

# %%
# Função para normalizar a idade
def normalize_age(age_band):
    age_mapping = {
        '0-35': 18,
        '35-55': 45,
        '55<=': 60
    }
    return age_mapping.get(age_band, 45)  # Valor padrão

# Aplicar a função de normalização de idade
data_oulad['/content/drive/MyDrive/mestrado/Emanoel/Datasets/oulad/studentInfo']['age'] = data_oulad['/content/drive/MyDrive/mestrado/Emanoel/Datasets/oulad/studentInfo']['age_band'].apply(normalize_age)

# %% [markdown]
# ## Normalização de sexo e gênero

# %%
# Normalizar gênero
data_uci['uci_sex'] = data_uci['uci_sex'].map({'F': 'Female', 'M': 'Male'})
data_oulad['/content/drive/MyDrive/mestrado/Emanoel/Datasets/oulad/studentInfo']['gender'] = data_oulad['/content/drive/MyDrive/mestrado/Emanoel/Datasets/oulad/studentInfo']['gender'].map({'F': 'Female', 'M': 'Male'})

# %% [markdown]
# ## Normalização de desempenho acadêmico

# %%
# Normalizar desempenho acadêmico (exemplo: converter para uma escala de 0 a 100)
data[['sintetico_números_inteiros', 'sintetico_frações', 'sintetico_equações', 'sintetico_geometria_básica',
     'sintetico_funções', 'sintetico_trigonometria', 'sintetico_probabilidade', 'sintetico_estatística']] *= 10

data_uci[['uci_g1', 'uci_g2', 'uci_g3']] = data_uci[['uci_g1', 'uci_g2', 'uci_g3']] * 10

# Access the studentAssessment DataFrame using its full path as the key
data_oulad['/content/drive/MyDrive/mestrado/Emanoel/Datasets/oulad/studentAssessment']['score'] = data_oulad['/content/drive/MyDrive/mestrado/Emanoel/Datasets/oulad/studentAssessment']['score'] * 10

# %% [markdown]
# ## Criação de chaves comuns

# %%
# Criar uma chave comum combinando informações de identificação de alunos, idade e gênero
data['common_key'] = data['unified_id'] + '_' + data['sintetico_aluno']
data_uci['common_key'] = data_uci['unified_id'] + '_' + data_uci['uci_age'].astype(str) + '_' + data_uci['uci_sex']

# Use the correct key to access the studentInfo DataFrame (without the .csv extension)
# Ensure 'unified_id' is converted to string before concatenation
data_oulad['/content/drive/MyDrive/mestrado/Emanoel/Datasets/oulad/studentInfo']['common_key'] = data_oulad['/content/drive/MyDrive/mestrado/Emanoel/Datasets/oulad/studentInfo']['unified_id'].astype(str) + '_' + data_oulad['/content/drive/MyDrive/mestrado/Emanoel/Datasets/oulad/studentInfo']['age'].astype(str) + '_' + data_oulad['/content/drive/MyDrive/mestrado/Emanoel/Datasets/oulad/studentInfo']['gender']

# %% [markdown]
# ## Integração de Dados de Cursos e Avaliações

# %%
# Adicionar colunas para incluir informações de cursos e avaliações
# Use as chaves corretas para acessar os DataFrames no dicionário data_oulad
# As chaves são os nomes dos arquivos sem a extensão .csv
student_info_key = '/content/drive/MyDrive/mestrado/Emanoel/Datasets/oulad/studentInfo'
courses_key = '/content/drive/MyDrive/mestrado/Emanoel/Datasets/oulad/courses'
assessments_key = '/content/drive/MyDrive/mestrado/Emanoel/Datasets/oulad/assessments'

data_oulad[student_info_key] = data_oulad[student_info_key].merge(data_oulad[courses_key], on=['code_module', 'code_presentation'])
data_oulad[student_info_key] = data_oulad[student_info_key].merge(data_oulad[assessments_key], on=['code_module', 'code_presentation'])

# %% [markdown]
# ## Tratamento de Valores Ausentes

# %%
# Preencher valores ausentes com um valor padrão
data.fillna(0, inplace=True)
data_uci.fillna(0, inplace=True)
# Use the correct key to access the studentInfo DataFrame
student_info_key = '/content/drive/MyDrive/mestrado/Emanoel/Datasets/oulad/studentInfo'
data_oulad[student_info_key].fillna(0, inplace=True)
# Out:
# <ipython-input-31-c2cb2d2e689e>:6: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data_oulad[student_info_key].fillna(0, inplace=True)

# %% [markdown]
# ## Conversão de Tipos de Dados

# %%
# Certificar-se de que todos os dados estejam no formato correto
# Print columns to debug
print(data.columns)
data['sintetico_números_inteiros'] = data['sintetico_números_inteiros'].astype(float)
data_uci['uci_age'] = data_uci['uci_age'].astype(int)
# Use a chave correta (caminho completo do arquivo) para acessar o DataFrame studentInfo
data_oulad['/content/drive/MyDrive/mestrado/Emanoel/Datasets/oulad/studentInfo']['age'] = data_oulad['/content/drive/MyDrive/mestrado/Emanoel/Datasets/oulad/studentInfo']['age'].astype(int)
# Out:
# Index(['sintetico_aluno', 'desempenho_numeros_inteiros', 'desempenho_fracoes',
#        'desempenho_equacoes', 'desempenho_geometria', 'desempenho_funcoes',
#        'desempenho_trigonometria', 'desempenho_probabilidade',
#        'desempenho_estatistica', 'unified_id', 'unified_key'],
#       dtype='object')
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# ...

# %%
# Certificar-se de que todos os dados estejam no formato correto
data['sintetico_números_inteiros'] = data['sintetico_números_inteiros'].astype(float)
data_uci['uci_age'] = data_uci['uci_age'].astype(int)
# Use a chave correta (caminho completo do arquivo) para acessar o DataFrame studentInfo
data_oulad['/content/drive/MyDrive/mestrado/Emanoel/Datasets/oulad/studentInfo']['age'] = data_oulad['/content/drive/MyDrive/mestrado/Emanoel/Datasets/oulad/studentInfo']['age'].astype(int)

# %% [markdown]
# Essas transformações ajudarão a criar um dataset unificado e consistente, pronto para ser usado como entrada para um sistema de identificação de dificuldades de aprendizagem acadêmica.
